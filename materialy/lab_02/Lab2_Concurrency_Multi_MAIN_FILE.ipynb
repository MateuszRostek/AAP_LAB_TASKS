# %% [markdown]
# # Laboratorium 2: Współbieżność i Równoległość w Pythonie
# ### Skoroszyt Edukacyjny - Wersja dla Studentów
#
# ---
#
# ## 1. Wstęp: Koncepcja "Wielu Zadań"
#
# Zanim zaczniemy pisać kod, musimy rozróżnić dwa kluczowe pojęcia:
#
# 1. **Współbieżność (Concurrency)**: Wykonywanie wielu zadań "na zmianę". Wyobraź sobie kelnera, który obsługuje 5 stolików. Nie robi wszystkiego naraz, ale szybko przełącza się między nimi. Dla klientów wygląda to, jakby obsługiwał ich równocześnie.
# 2. **Równoległość (Parallelism)**: Wykonywanie wielu zadań faktycznie w tym samym momencie. To sytuacja, w której mamy 5 kelnerów i każdy obsługuje jeden stolik.
#
# W Pythonie współbieżność realizujemy najczęściej za pomocą **Wątków (Threads)**, a równoległość za pomocą **Procesów (Processes)**.
#
# ---

# %% [markdown]
# ## 2. Wielowątkowość (Threading) - Zadania I/O-bound
#
# Wątki są idealne, gdy program większość czasu spędza na **czekaniu** na odpowiedź z sieci (zapytania HTTP). W tym czasie procesor się nudzi – wątki pozwalają mu wysłać kolejne zapytania, nie czekając na poprzednie.
#
# ---

# %% [markdown]
# ### Demo: Scraping Kalendarza Kulturalnego (Krakow.pl)
#
# **Kod zawarty w poniższych komórkach (analogicznie do plików `lab_2_1_demo.py` oraz `lab_2_2_demo.py`) pozwala na pobieranie tytułów wydarzeń kulturalnych z oficjalnego kalendarium miasta Krakowa (krakow.pl).**
#
# Przykładowy adres źródłowy: `https://www.krakow.pl/kalendarium/1919,shw,2026-03-20,0,day.html`.
#
# Demo pokazuje proces pobierania danych z 5 kolejnych stron tego zestawienia:
# 1. **Wersja sekwencyjna**: Zadanie wykonywane jest krok po kroku, co pozwala zaobserwować sumaryczny czas oczekiwania na każde z zapytań HTTP z osobna (wysoki koszt operacji wejścia/wyjścia).
# 2. **Optymalizacja**: Kod zostaje zmodyfikowany z użyciem modułu `concurrent.futures`, wykorzystując `ThreadPoolExecutor`.
#
# Dzięki temu zapytania sieciowe są wysyłane równolegle, co drastycznie skraca czas całkowity działania programu, demonstrując praktyczną przewagę wielowątkowości w zadaniach typu **I/O-bound** (zależnych od odpowiedzi sieciowej).

# %%
import requests
from bs4 import BeautifulSoup
import time

def download_site(url):
    """Pobiera jedną stronę i wyciąga tytuły wydarzeń."""
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    event_titles = [item.text.strip() for item in soup.select('.item__link h3')]
    return event_titles

def run_sequential_demo():
    date_str = "2026-03-20"
    base_url = "https://www.krakow.pl/kalendarium/1919,shw"
    sites = [f"{base_url},{date_str},{i},day.html" for i in range(5)]
    
    print(f"Rozpoczynam pobieranie SEKWENCYJNE 5 stron...")
    start = time.time()
    
    all_titles = []
    for url in sites:
        all_titles.extend(download_site(url))
        
    print(f"Pobrano łącznie {len(all_titles)} tytułów.")
    print("Pierwsze 10 wyników:")
    for i, title in enumerate(all_titles[:10], 1):
        print(f"{i}. {title}")
        
    print(f"\nCzas wykonania: {time.time() - start:.2f}s")

run_sequential_demo()
# Out:
# Rozpoczynam pobieranie SEKWENCYJNE 5 stron...
# Pobrano łącznie 100 tytułów.
# Pierwsze 10 wyników:
# 1. Piosenka kabaretowa
# 2. Kakofonie #15: Mariusze Figle / Tomek Przetacznik / Patryk Zakrocki
# 3. Preskot
# 4. Królowa
# 5. Piramida zwierząt
# 6. Gdzie gubią się zdania
# 7. Cnoty niewieście albo dziwki w majonezie wg „Szewców” Witkacego
# 8. ART — TALKS. Przeszłość Przyszłości — krakowska szkoła grafiki
# 9. Wielki Gatsby
# 10. Chłopcy z Placu Broni
#
# Czas wykonania: 3.39s

# %%
import concurrent.futures

def run_threaded_demo():
    date_str = "2026-03-20"
    base_url = "https://www.krakow.pl/kalendarium/1919,shw"
    sites = [f"{base_url},{date_str},{i},day.html" for i in range(5)]
    
    print(f"Rozpoczynam pobieranie WIELOWĄTKOWE 5 stron...")
    start = time.time()
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        results = list(executor.map(download_site, sites))
    
    all_titles = [title for sublist in results for title in sublist]
    
    print(f"Pobrano łącznie {len(all_titles)} tytułów.")
    print("Pierwsze 10 wyników:")
    for i, title in enumerate(all_titles[:10], 1):
        print(f"{i}. {title}")
        
    print(f"\nCzas wykonania (wątki): {time.time() - start:.2f}s")

run_threaded_demo()
# Out:
# Rozpoczynam pobieranie WIELOWĄTKOWE 5 stron...
# Pobrano łącznie 100 tytułów.
# Pierwsze 10 wyników:
# 1. Piosenka kabaretowa
# 2. Kakofonie #15: Mariusze Figle / Tomek Przetacznik / Patryk Zakrocki
# 3. Preskot
# 4. Królowa
# 5. Piramida zwierząt
# 6. Gdzie gubią się zdania
# 7. Cnoty niewieście albo dziwki w majonezie wg „Szewców” Witkacego
# 8. ART — TALKS. Przeszłość Przyszłości — krakowska szkoła grafiki
# 9. Wielki Gatsby
# 10. Chłopcy z Placu Broni
#
# Czas wykonania (wątki): 0.79s

# %% [markdown]
# ---
# ## 3. Synchronizacja: Problem Hazardu i Lock
#
# Gdy wiele wątków próbuje zmieniać tę samą zmienną w tym samym momencie (np. saldo na koncie), dochodzi do tzw. **Race Condition** (wyścigu). Rozwiązaniem jest **Lock** (blokada).

# %%
import threading

class BankAccount:
    def __init__(self):
        self.balance = 0
        self.lock = threading.Lock()

    def deposit(self, amount):
        with self.lock:
            current = self.balance
            time.sleep(0.0001) # Symulacja opóźnienia
            self.balance = current + amount

account = BankAccount()
with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
    executor.map(lambda _: account.deposit(1), range(100))
    
print(f"Saldo końcowe: {account.balance} zł (oczekiwano: 100)")
# Out:
# Saldo końcowe: 100 zł (oczekiwano: 100)

# %% [markdown]
# ---
# ## 4. Wieloprocesowość (Multiprocessing) - Zadania CPU-bound
#
# Kiedy musimy wykonać ciężkie obliczenia matematyczne (np. szukanie liczb pierwszych), wątki nam nie pomogą. Musimy użyć osobnych procesów.
#
# **Ważne (macOS/Windows)**: Ze względu na metodę `spawn` startu procesów, funkcje pomocnicze (jak `find_primes`) muszą znajdować się w zewnętrznym pliku `.py` (tutaj: `lab2_functions.py`) i być importowane.

# %%
import multiprocessing
import time
# Importujemy funkcję z oddzielnego pliku, aby uniknąć błędu spawn na macOS
from lab2_functions import find_primes

def run_primes_demo():
    cores = multiprocessing.cpu_count()
    print(f"Praca na {cores} procesach (rdzeniach)...")
    start = time.time()

    limit = 2_000_000
    chunk = limit // cores
    ranges = [(i, i + chunk) for i in range(0, limit, chunk)]

    with multiprocessing.Pool(processes=cores) as pool:
        results = pool.starmap(find_primes, ranges)
    
    print(f"Zakończono w czasie {time.time() - start:.2f}s.")

if __name__ == "__main__":
    run_primes_demo()
# Out:
# Praca na 12 procesach (rdzeniach)...
# Zakończono w czasie 3.41s.

# %% [markdown]
# ---
# # Zadania do samodzielnego wykonania
#
# Poniższe zadania należy zrealizować w oparciu o wiedzę zdobytą na laboratoriach oraz instrukcje zawarte w pliku PDF.

# %% [markdown]
# ### Zadanie 1 (Threading)
# Przy użyciu publicznego API **Cat Facts** (`https://catfact.ninja/fact`), które zwraca przy każdym wywołaniu losowy fakt na temat kotów:
# 1. Pobierz sekwencyjnie 20 faktów i zmierz czas całkowitego działania programu.
# 2. Zmodyfikuj kod, aby wysyłać zapytania wielowątkowo przy użyciu `ThreadPoolExecutor`.
# 3. Porównaj czasy wykonania.
#
# *Podpowiedź: Użyj `requests.get(URL).json().get('fact')`*

# %%
# Miejsce na rozwiązanie zadania 1
import requests
import time
import concurrent.futures as cf

CAT_API_URL = "https://catfact.ninja/fact"

def download_fact():
    fact = requests.get(CAT_API_URL).json().get('fact')
    return fact


def run_sequential():
    print(f"Rozpoczynam pobieranie SEKWENCYJNE 20 faktów...")
    start = time.time()

    all_facts = []
    for _ in range(20):
        all_facts.append(download_fact())

    print(f"Pobrano łącznie {len(all_facts)} faktów:")
    for i, fact in enumerate(all_facts, 1):
        print(f"{i}. {fact}")
    print(f"\nCzas wykonania: {time.time() - start:.2f}s")

def run_threads():
    print(f"Rozpoczynam pobieranie z użyciem wątków 20 faktów...")
    start = time.time()

    with cf.ThreadPoolExecutor(max_workers=20) as executor:
        results = [executor.submit(download_fact) for _ in range(20)]
        all_facts = [r.result() for r in results]

    print(f"Pobrano łącznie {len(all_facts)} faktów:")
    for i, fact in enumerate(all_facts, 1):
        print(f"{i}. {fact}")
    print(f"\nCzas wykonania: {time.time() - start:.2f}s")

run_sequential()
run_threads()
# Out:
# Rozpoczynam pobieranie SEKWENCYJNE 20 faktów...
# Pobrano łącznie 20 faktów:
# 1. In Holland’s embassy in Moscow, Russia, the staff noticed that the two Siamese cats kept meowing and clawing at the walls of the building. Their owners finally investigated, thinking they would find mice. Instead, they discovered microphones hidden by Russian spies. The cats heard the microphones when they turned on.
# 2. The life expectancy of cats has nearly doubled since 1930 - from 8 to 16 years.
# 3. Cats can be taught to walk on a leash, but a lot of time and patience is required to teach them. The younger the cat is, the easier it will be for them to learn.
# 4. Contrary to popular belief, the cat is a social animal. A pet cat will respond and answer to speech , and seems to enjoy human companionship.
# 5. The largest cat breed is the Ragdoll. Male Ragdolls weigh between 12 and 20 lbs (5.4-9.0 k). Females weigh between 10 and 15 lbs (4.5-6.8 k).
# 6. Mountain lions are strong jumpers, thanks to muscular hind legs that are longer than their front legs.
# 7. Two members of the cat family are distinct from all others: the clouded leopard and the cheetah. The clouded leopard does not roar like other big cats, nor does it groom or rest like small cats. The cheetah is unique because it is a running cat; all others are leaping cats. They are leaping cats because they slowly stalk their prey and then leap on it.
# 8. Miacis, the primitive ancestor of cats, was a small, tree-living creature of the late Eocene period, some 45 to 50 million years ago.
# 9. A cat can jump 5 times as high as it is tall.
# 10. A cat named Dusty, aged 1 7, living in Bonham, Texas, USA, gave birth to her 420th kitten on June 23, 1952.
# 11. A cat's normal temperature varies around 101 degrees Fahrenheit.
# 12. The ability of a cat to find its way home is called “psi-traveling.” Experts think cats either use the angle of the sunlight to find their way or that cats have magnetized cells in their brains that act as compasses.
# 13. Fossil records from two million years ago show evidence of jaguars.
# 14. A kitten will typically weigh about 3 ounces at birth.  The typical male housecat will weigh between  7 and 9 pounds, slightly less for female housecats.
# 15. Retractable claws are a physical phenomenon that sets cats apart from the rest of the animal kingdom. I n the cat family, only cheetahs cannot retract their claws.
# 16. Abraham Lincoln loved cats. He had four of them while he lived in the White House.
# 17. Cats respond better to women than to men, probably due to the fact that women's voices have a higher pitch.
# 18. Cats prefer to remain non-confrontational. They will not fight to show dominance, but rather to stake their territory. Cats will actually go to extremes to avoid one another in order to prevent a possible confrontation.
# 19. Tests done by the Behavioral Department of the Musuem of Natural History conclude that while a dog's memory lasts about 5 minutes, a cat's recall can last as long as 16 hours.
# 20. An adult lion's roar can be heard up to five miles (eight kilometers) away.
#
# Czas wykonania: 4.54s
# Rozpoczynam pobieranie z użyciem wątków 20 faktów...
# Pobrano łącznie 20 faktów:
# 1. Researchers are unsure exactly how a cat purrs. Most veterinarians believe that a cat purrs by vibrating vocal folds deep in the throat. To do this, a muscle in the larynx opens and closes the air passage about 25 times per second.
# 2. Cats lived with soldiers in trenches, where they killed mice during World War I.
# 3. A kitten will typically weigh about 3 ounces at birth.  The typical male housecat will weigh between  7 and 9 pounds, slightly less for female housecats.
# 4. Unlike dogs, cats do not have a sweet tooth. Scientists believe this is due to a mutation in a key taste receptor.
# 5. The earliest ancestor of the modern cat lived about 30 million years ago. Scientists called it the Proailurus, which means “first cat” in Greek. The group of animals that pet cats belong to emerged around 12 million years ago.
# 6. The cat's clavicle, or collarbone, does not connect with other bones but is buried in the muscles of the shoulder region. This lack of a functioning collarbone allows them to fit through any opening the size of their head.
# 7. A female cat can be referred to as a molly or a queen, and a male cat is often labeled as a tom.
# 8. A cat's appetite is the barometer of its health. Any cat that does not eat or drink for more than two days should be taken to a vet.
# 9. Cats eat grass to aid their digestion and to help them get rid of any fur in their stomachs.
# 10. Grown cats have 30 teeth. Kittens have about 26 temporary teeth, which they lose when they are about 6 months old.
# 11. A cat sees about 6 times better than a human at night, and needs 1/6 the amount of of light that a human does - it has a layer of extra reflecting cells which absorb light.
# 12. The tiniest cat on record is Mr. Pebbles, a 2-year-old cat that weighed 3 lbs (1.3 k) and was 6.1 inches (15.5 cm) high.
# 13. Tylenol and chocolate are both poisionous to cats.
# 14. The female cat reaches sexual maturity within 6 to 10 months; most veterinarians suggest spaying the female at 5 months, before her first heat period. The male cat usually reaches sexual maturity between 9 and 12 months.
# 15. Cheetahs do not roar, as the other big cats do. Instead, they purr.
# 16. In the 1750s, Europeans introduced cats into the Americas to control pests.
# 17. Most cats adore sardines.
# 18. A cat has more bones than a human being; humans have 206 and the cat has 230 bones.
# 19. Purring does not always indicate that a cat is happy. Cats will also purr loudly when they are distressed or in pain.
# 20. Approximately 24 cat skins can make a coat.
#
# Czas wykonania: 0.83s

# %% [markdown]
# ### Zadanie 2 (Wątki i Kolejka - Producent-Konsument)
# Napisz program o strukturze **producent-consumers**:
# 1. **Producent**: Generuje kolejne liczby naturalne i dodaje je do kolejki (`queue.Queue`).
# 2. **Konsument 1**: Pobiera z kolejki tylko liczby **parzyste**.
# 3. **Konsument 2**: Pobiera z kolejki tylko liczby **nieparzyste**.
#
# Użyj wątków do realizacji producenta i obu konsumentów. Program powinien zakończyć się po przetworzeniu określonej puli liczb.

# %%
# Miejsce na rozwiązanie zadania 2
import queue
import threading

END_VALUE = None

def producer(q: queue.Queue, quantity: int):
    for i in range(quantity):
        q.put(i)

def consumer_odd(q: queue.Queue):
    while True:
        value = q.get()

        if value is END_VALUE:
            q.task_done()
            break

        if value % 2 == 0:
            q.put(value)
        else:
            print(f"Odd consumer got odd value: {value}")
        q.task_done()

def consumer_even(q: queue.Queue):
    while True:
        value = q.get()

        if value is END_VALUE:
            q.task_done()
            break

        if value % 2 == 1:
            q.put(value)
        else:
            print(f"Even consumer got even value: {value}")
        q.task_done()

q = queue.Queue()
producer_thread = threading.Thread(target=producer, args=(q, 100,))
odd_consumer_thread = threading.Thread(target=consumer_odd, args=(q,))
even_consumer_thread = threading.Thread(target=consumer_even, args=(q,))

producer_thread.start()
odd_consumer_thread.start()
even_consumer_thread.start()

producer_thread.join()
q.join()

q.put(END_VALUE)
q.put(END_VALUE)

odd_consumer_thread.join()
even_consumer_thread.join()

print("main thread finished")
# Out:
# Odd consumer got odd value: 1
# Odd consumer got odd value: 3
# Odd consumer got odd value: 5
# Odd consumer got odd value: 7
# Odd consumer got odd value: 9
# Odd consumer got odd value: 11
# Odd consumer got odd value: 13
# Odd consumer got odd value: 15
# Odd consumer got odd value: 17
# Odd consumer got odd value: 19
# Odd consumer got odd value: 21
# Odd consumer got odd value: 23
# Odd consumer got odd value: 25
# Odd consumer got odd value: 27
# Odd consumer got odd value: 29
# Odd consumer got odd value: 31
# Odd consumer got odd value: 33
# Odd consumer got odd value: 35
# Odd consumer got odd value: 37
# Odd consumer got odd value: 39
# Odd consumer got odd value: 41
# Odd consumer got odd value: 43
# Odd consumer got odd value: 45
# Odd consumer got odd value: 47
# Odd consumer got odd value: 49
# Odd consumer got odd value: 51
# Odd consumer got odd value: 53
# Odd consumer got odd value: 55
# Odd consumer got odd value: 57
# Odd consumer got odd value: 59
# Odd consumer got odd value: 61
# Odd consumer got odd value: 63
# Odd consumer got odd value: 65
# Odd consumer got odd value: 67
# Odd consumer got odd value: 69
# Odd consumer got odd value: 71
# Odd consumer got odd value: 73
# Odd consumer got odd value: 75
# Odd consumer got odd value: 77
# Odd consumer got odd value: 79
# Odd consumer got odd value: 81
# Odd consumer got odd value: 83
# Odd consumer got odd value: 85
# Odd consumer got odd value: 87
# Odd consumer got odd value: 89
# Odd consumer got odd value: 91
# Odd consumer got odd value: 93
# Odd consumer got odd value: 95
# Odd consumer got odd value: 97
# Odd consumer got odd value: 99
# Even consumer got even value: 88
# Even consumer got even value: 90
# Even consumer got even value: 92
# Even consumer got even value: 94
# Even consumer got even value: 96
# Even consumer got even value: 98
# Even consumer got even value: 0
# Even consumer got even value: 2
# Even consumer got even value: 4
# Even consumer got even value: 6
# Even consumer got even value: 8
# Even consumer got even value: 10
# Even consumer got even value: 12
# Even consumer got even value: 14
# Even consumer got even value: 16
# Even consumer got even value: 18
# Even consumer got even value: 20
# Even consumer got even value: 22
# Even consumer got even value: 24
# Even consumer got even value: 26
# Even consumer got even value: 28
# Even consumer got even value: 30
# Even consumer got even value: 32
# Even consumer got even value: 34
# Even consumer got even value: 36
# Even consumer got even value: 38
# Even consumer got even value: 40
# Even consumer got even value: 42
# Even consumer got even value: 44
# Even consumer got even value: 46
# Even consumer got even value: 48
# Even consumer got even value: 50
# Even consumer got even value: 52
# Even consumer got even value: 54
# Even consumer got even value: 56
# Even consumer got even value: 58
# Even consumer got even value: 60
# Even consumer got even value: 62
# Even consumer got even value: 64
# Even consumer got even value: 66
# Even consumer got even value: 68
# Even consumer got even value: 70
# Even consumer got even value: 72
# Even consumer got even value: 74
# Even consumer got even value: 76
# Even consumer got even value: 78
# Even consumer got even value: 80
# Even consumer got even value: 82
# Even consumer got even value: 84
# Even consumer got even value: 86
# main thread finished

# %% [markdown]
# ### Zadanie 3 (Multiprocessing)
# Napisz program, który zrównolegli obliczanie sumy kolejnych stu potęg dla każdej liczby z ciągu liczb naturalnych w dużym zakresie (np. 1 - 10 000).
# Użyj modułu `multiprocessing` oraz gotowej funkcji `calculate_power_sum(n)` z pliku `lab2_functions.py`.
#
# Pamiętaj o bezpiecznym uruchamianiu procesów na macOS (`if __name__ == "__main__":`).

# %%
# Miejsce na rozwiązanie zadania 3
import multiprocessing
import time
from lab2_functions import calculate_power_sum

if __name__ == "__main__":
    cores = multiprocessing.cpu_count()
    begin = 1
    limit = 100_000
    start = time.time()
    with multiprocessing.Pool(cores) as pool:
        pool.map(calculate_power_sum, range(begin, limit))

    print(f"Execution time: {time.time() - start:.2f}s")
# Out:
# Execution time: 1.10s
